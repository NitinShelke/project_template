# %%
import os
os.chdir("..")
from project import logger

# %%
os.listdir()
# Out:
# ['.git',
#  '.github',
#  '.gitignore',
#  '.pre-commit-config.yaml',
#  '.python-version',
#  '.venv',
#  'config',
#  'Loggings',
#  'notebooks',
#  'pyproject.toml',
#  'README.md',
#  'src',
#  'test',
#  'uv.lock']

# %%
logger.info("testing")
